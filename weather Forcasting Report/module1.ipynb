# %%
import pandas as pd
import numpy as np

# %%
weather=pd.read_excel("C:/Users/Ramakrishna/Desktop/weather Forcasting Report/weather_dataset_stage1 (1).xls")

# %%
weather
# Out:
#              Date  Temperature  Average humidity (%  Average dewpoint (°F  \
# 0      2022-01-01       '37.8'               '35.0'                '12.7'
# 1     2022-01-02'       '43.2'               '32.0'                '14.7'
# 2     2022-01-03'       '25.7'               '60.0'                '12.7'
# 3     2022-01-04'        '9.3'               '67.0'                 '0.1'
# 4     2022-01-05'       '23.5'               '30.0'                '-5.3'
# ...           ...          ...                  ...                   ...
# 3898  2022-07-25'       '62.8'               '60.0'                '48.1'
# 3899  2022-07-26'       '60.6'               '68.0'                '48.9'
# 3900  2022-07-27'       '61.7'               '64.0'                '47.4'
# 3901  2022-07-28'       '60.5'               '61.0'                '45.3'
# 3902  2022-07-28'       '60.5'               '61.0'                '45.3'
#
#       Average barometer (in  Average windspeed (mph  Average gustspeed (mph  \
# ...

# %%
weather.isnull()
# Out:
#        Date   Temperature   Average humidity (%   Average dewpoint (°F  \
# 0     False         False                 False                  False
# 1     False         False                 False                  False
# 2     False         False                 False                  False
# 3     False         False                 False                  False
# 4     False         False                 False                  False
# ...     ...           ...                   ...                    ...
# 3898  False         False                 False                  False
# 3899  False         False                 False                  False
# 3900  False         False                 False                  False
# 3901  False         False                 False                  False
# 3902  False         False                 False                  False
#
#        Average barometer (in   Average windspeed (mph  \
# 0                      False                    False
# ...

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3903 entries, 0 to 3902
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Date                      3903 non-null   object
#  1    Temperature              3903 non-null   object
#  2    Average humidity (%      3903 non-null   object
#  3    Average dewpoint (°F     3903 non-null   object
#  4    Average barometer (in    3903 non-null   object
#  5    Average windspeed (mph   3903 non-null   object
#  6    Average gustspeed (mph   3903 non-null   object
#  7    Average direction (°deg  3903 non-null   object
#  8    Rainfall for month (in   3903 non-null   object
#  9   Rainfall for year (in     3903 non-null   object
#  10   Maximum rain per minute  3903 non-null   object
#  11   Maximum temperature (°F  3903 non-null   object
#  12   Minimum temperature (°F  3903 non-null   object
# ...

# %%
weather.shape
# Out:
# (3903, 23)

# %%
weather.columns
# Out:
# Index(['Date', ' Temperature', ' Average humidity (%', ' Average dewpoint (°F',
#        ' Average barometer (in', ' Average windspeed (mph',
#        ' Average gustspeed (mph', ' Average direction (°deg',
#        ' Rainfall for month (in', 'Rainfall for year (in',
#        ' Maximum rain per minute', ' Maximum temperature (°F',
#        ' Minimum temperature (°F', ' Maximum humidity (%',
#        ' Minimum humidity (%', ' Maximum pressure', ' Minimum pressure',
#        ' Maximum windspeed (mph', ' Maximum gust speed (mph',
#        ' Maximum heat index (°F', 'Date1', ' Month', ' diff_pressure'],
#       dtype='object')

# %%
weather[' Temperature'].dtype
# Out:
# dtype('O')

# %%
weather
# Out:
#              Date  Temperature  Average humidity (%  Average dewpoint (°F  \
# 0      2022-01-01       '37.8'               '35.0'                '12.7'
# 1     2022-01-02'       '43.2'               '32.0'                '14.7'
# 2     2022-01-03'       '25.7'               '60.0'                '12.7'
# 3     2022-01-04'        '9.3'               '67.0'                 '0.1'
# 4     2022-01-05'       '23.5'               '30.0'                '-5.3'
# ...           ...          ...                  ...                   ...
# 3898  2022-07-25'       '62.8'               '60.0'                '48.1'
# 3899  2022-07-26'       '60.6'               '68.0'                '48.9'
# 3900  2022-07-27'       '61.7'               '64.0'                '47.4'
# 3901  2022-07-28'       '60.5'               '61.0'                '45.3'
# 3902  2022-07-28'       '60.5'               '61.0'                '45.3'
#
#       Average barometer (in  Average windspeed (mph  Average gustspeed (mph  \
# ...

# %% [markdown]
# #  Fix The Labels and Values

# %%
weather[' Average humidity (%'] = weather[' Average humidity (%'].str.replace("'",'').astype(float)

# %%
weather[' Average dewpoint (°F']= weather[' Average dewpoint (°F'].str.replace("'",'').astype(float)

# %%
weather[' Average barometer (in']=  weather[' Average barometer (in'].str.replace("'",'').astype(float)

# %%
weather[' Average windspeed (mph']= weather[' Average windspeed (mph'].str.replace("'",'').astype(float)

# %%
weather[' Average gustspeed (mph']= weather[' Average gustspeed (mph'].str.replace("'",'').astype(float)

# %%
weather[' Average direction (°deg']= weather[' Average direction (°deg'].str.replace("'",'').astype(float)

# %%
weather[' Rainfall for month (in']= weather[' Rainfall for month (in'].str.replace("'",'').astype(float)

# %%
weather['Rainfall for year (in']= weather['Rainfall for year (in'].str.replace("'",'').astype(float)

# %%
weather[' Maximum rain per minute'] = weather[' Maximum rain per minute'].str.replace("'",'').astype(float)

# %%
weather[' Maximum temperature (°F'] = weather[' Maximum temperature (°F'].str.replace("'",'').astype(float)

# %%
weather[' Minimum temperature (°F']= weather[' Minimum temperature (°F'].str.replace("'",'').astype(float)

# %%
weather[' Maximum humidity (%'] = weather[' Maximum humidity (%'].str.replace("'",'').astype(float)

# %%
weather[' Minimum humidity (%'] = weather[' Minimum humidity (%'].str.replace("'",'').astype(float)

# %%
weather[' Maximum pressure']= weather[' Maximum pressure'].str.replace("'",'').astype(float)

# %%
weather[' Minimum pressure'] = weather[' Minimum pressure'].str.replace("'",'').astype(float)

# %%
weather[' Maximum windspeed (mph'] = weather[' Maximum windspeed (mph'].str.replace("'",'').astype(float)

# %%
weather[' Maximum gust speed (mph'] = weather[' Maximum gust speed (mph'].str.replace("'",'').astype(float)

# %%
weather[' Maximum heat index (°F']= weather[' Maximum heat index (°F'].str.replace("'",'').astype(float)

# %%
weather['Date1']= weather['Date1'].str.replace("'",'')

# %%
weather[' Month']= weather[' Month'].str.replace("'",'')

# %%
weather[' diff_pressure']= weather[' diff_pressure'].str.replace("'",'')

# %%
weather[' Temperature']= weather[' Temperature'].str.replace("'",'').astype(float)

# %%
weather['Date']= weather['Date'].str.replace("'",'')

# %% [markdown]
# ## After Fix the labels and values

# %%
weather
# Out:
#             Date   Temperature   Average humidity (%   Average dewpoint (°F  \
# 0     2022-01-01          37.8                  35.0                   12.7
# 1     2022-01-02          43.2                  32.0                   14.7
# 2     2022-01-03          25.7                  60.0                   12.7
# 3     2022-01-04           9.3                  67.0                    0.1
# 4     2022-01-05          23.5                  30.0                   -5.3
# ...          ...           ...                   ...                    ...
# 3898  2022-07-25          62.8                  60.0                   48.1
# 3899  2022-07-26          60.6                  68.0                   48.9
# 3900  2022-07-27          61.7                  64.0                   47.4
# 3901  2022-07-28          60.5                  61.0                   45.3
# 3902  2022-07-28          60.5                  61.0                   45.3
#
#        Average barometer (in   Average windspeed (mph  \
# ...

# %% [markdown]
# #  Remove the duplicate rows

# %%
weather.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3898    False
# 3899    False
# 3900    False
# 3901    False
# 3902     True
# Length: 3903, dtype: bool

# %%
weather=weather.drop_duplicates()

# %%
weather.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3897    False
# 3898    False
# 3899    False
# 3900    False
# 3901    False
# Length: 3902, dtype: bool

# %%
weather['Date']
# Out:
# 0       2022-01-01
# 1       2022-01-02
# 2       2022-01-03
# 3       2022-01-04
# 4       2022-01-05
#            ...
# 3897    2022-07-24
# 3898    2022-07-25
# 3899    2022-07-26
# 3900    2022-07-27
# 3901    2022-07-28
# Name: Date, Length: 3902, dtype: object

# %%
weather.columns
# Out:
# Index(['Date', ' Temperature', ' Average humidity (%', ' Average dewpoint (°F',
#        ' Average barometer (in', ' Average windspeed (mph',
#        ' Average gustspeed (mph', ' Average direction (°deg',
#        ' Rainfall for month (in', 'Rainfall for year (in',
#        ' Maximum rain per minute', ' Maximum temperature (°F',
#        ' Minimum temperature (°F', ' Maximum humidity (%',
#        ' Minimum humidity (%', ' Maximum pressure', ' Minimum pressure',
#        ' Maximum windspeed (mph', ' Maximum gust speed (mph',
#        ' Maximum heat index (°F', 'Date1', ' Month', ' diff_pressure'],
#       dtype='object')

# %% [markdown]
# ## Deleting Duplicate columns

# %%
weather=weather.drop('Date1',axis=1)

# %%
weather
# Out:
#             Date   Temperature   Average humidity (%   Average dewpoint (°F  \
# 0     2022-01-01          37.8                  35.0                   12.7
# 1     2022-01-02          43.2                  32.0                   14.7
# 2     2022-01-03          25.7                  60.0                   12.7
# 3     2022-01-04           9.3                  67.0                    0.1
# 4     2022-01-05          23.5                  30.0                   -5.3
# ...          ...           ...                   ...                    ...
# 3897  2022-07-24          64.1                  62.0                   49.8
# 3898  2022-07-25          62.8                  60.0                   48.1
# 3899  2022-07-26          60.6                  68.0                   48.9
# 3900  2022-07-27          61.7                  64.0                   47.4
# 3901  2022-07-28          60.5                  61.0                   45.3
#
#        Average barometer (in   Average windspeed (mph  \
# ...

# %%
year = 2022

weather['Date'][0] = "'" + str(year) + weather['Date'][0][4:] + "'"
for i in range(1, len(weather)):
    curr_month = int(weather['Date'][i][5:7])
    prev_month = int(weather['Date'][i-1][6:8])
    if curr_month < prev_month:
        year += 1
    weather['Date'][i] = "'" + str(year) + weather['Date'][i][4:]
    print(year)
# Out:
# C:\Users\Ramakrishna\AppData\Local\Temp\ipykernel_4524\1516050955.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weather['Date'][0] = "'" + str(year) + weather['Date'][0][4:] + "'"
# C:\Users\Ramakrishna\AppData\Local\Temp\ipykernel_4524\1516050955.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weather['Date'][i] = "'" + str(year) + weather['Date'][i][4:]
# 2022
# 2022
# 2022
# 2022
# 2022
# 2022
# 2022
# 2022
# 2022
# 2022
# 2022
# 2022
# 2022
# 2022
# 2022
# 2022
# 2022
# 2022
# 2022
# 2022
# 2022
# 2022
# 2022
# 2022
# 2022
# 2022
# 2022
# 2022
# 2022
# 2022
# 2022
# 2022
# 2022
# 2022
# ...

# %%
weather
# Out:
#               Date   Temperature   Average humidity (%   Average dewpoint (°F  \
# 0     '2022-01-01'          37.8                  35.0                   12.7
# 1      '2022-01-02          43.2                  32.0                   14.7
# 2      '2022-01-03          25.7                  60.0                   12.7
# 3      '2022-01-04           9.3                  67.0                    0.1
# 4      '2022-01-05          23.5                  30.0                   -5.3
# ...            ...           ...                   ...                    ...
# 3897   '2033-07-24          64.1                  62.0                   49.8
# 3898   '2033-07-25          62.8                  60.0                   48.1
# 3899   '2033-07-26          60.6                  68.0                   48.9
# 3900   '2033-07-27          61.7                  64.0                   47.4
# 3901   '2033-07-28          60.5                  61.0                   45.3
#
# ...

# %%
weather['Date']= weather['Date'].str.replace("'",'')

# %%
weather
# Out:
#             Date   Temperature   Average humidity (%   Average dewpoint (°F  \
# 0     2022-01-01          37.8                  35.0                   12.7
# 1     2022-01-02          43.2                  32.0                   14.7
# 2     2022-01-03          25.7                  60.0                   12.7
# 3     2022-01-04           9.3                  67.0                    0.1
# 4     2022-01-05          23.5                  30.0                   -5.3
# ...          ...           ...                   ...                    ...
# 3897  2033-07-24          64.1                  62.0                   49.8
# 3898  2033-07-25          62.8                  60.0                   48.1
# 3899  2033-07-26          60.6                  68.0                   48.9
# 3900  2033-07-27          61.7                  64.0                   47.4
# 3901  2033-07-28          60.5                  61.0                   45.3
#
#        Average barometer (in   Average windspeed (mph  \
# ...

# %%
data= weather.copy()

# %%
data = data[data['Date'] != '2029-02-29']

# %%
data
# Out:
#             Date   Temperature   Average humidity (%   Average dewpoint (°F  \
# 0     2022-01-01          37.8                  35.0                   12.7
# 1     2022-01-02          43.2                  32.0                   14.7
# 2     2022-01-03          25.7                  60.0                   12.7
# 3     2022-01-04           9.3                  67.0                    0.1
# 4     2022-01-05          23.5                  30.0                   -5.3
# ...          ...           ...                   ...                    ...
# 3897  2033-07-24          64.1                  62.0                   49.8
# 3898  2033-07-25          62.8                  60.0                   48.1
# 3899  2033-07-26          60.6                  68.0                   48.9
# 3900  2033-07-27          61.7                  64.0                   47.4
# 3901  2033-07-28          60.5                  61.0                   45.3
#
#        Average barometer (in   Average windspeed (mph  \
# ...

# %%
data['Date'] = pd.to_datetime(data['Date'], format ="%Y-%m-%d", errors='coerce')

# %%
data
# Out:
#            Date   Temperature   Average humidity (%   Average dewpoint (°F  \
# 0    2022-01-01          37.8                  35.0                   12.7
# 1    2022-01-02          43.2                  32.0                   14.7
# 2    2022-01-03          25.7                  60.0                   12.7
# 3    2022-01-04           9.3                  67.0                    0.1
# 4    2022-01-05          23.5                  30.0                   -5.3
# ...         ...           ...                   ...                    ...
# 3897 2033-07-24          64.1                  62.0                   49.8
# 3898 2033-07-25          62.8                  60.0                   48.1
# 3899 2033-07-26          60.6                  68.0                   48.9
# 3900 2033-07-27          61.7                  64.0                   47.4
# 3901 2033-07-28          60.5                  61.0                   45.3
#
#        Average barometer (in   Average windspeed (mph  \
# ...

# %%
data
# Out:
#            Date   Temperature   Average humidity (%   Average dewpoint (°F  \
# 0    2022-01-01          37.8                  35.0                   12.7
# 1    2022-01-02          43.2                  32.0                   14.7
# 2    2022-01-03          25.7                  60.0                   12.7
# 3    2022-01-04           9.3                  67.0                    0.1
# 4    2022-01-05          23.5                  30.0                   -5.3
# ...         ...           ...                   ...                    ...
# 3897 2033-07-24          64.1                  62.0                   49.8
# 3898 2033-07-25          62.8                  60.0                   48.1
# 3899 2033-07-26          60.6                  68.0                   48.9
# 3900 2033-07-27          61.7                  64.0                   47.4
# 3901 2033-07-28          60.5                  61.0                   45.3
#
#        Average barometer (in   Average windspeed (mph  \
# ...

# %%
weather=data.copy()

# %%
weather
# Out:
#            Date   Temperature   Average humidity (%   Average dewpoint (°F  \
# 0    2022-01-01          37.8                  35.0                   12.7
# 1    2022-01-02          43.2                  32.0                   14.7
# 2    2022-01-03          25.7                  60.0                   12.7
# 3    2022-01-04           9.3                  67.0                    0.1
# 4    2022-01-05          23.5                  30.0                   -5.3
# ...         ...           ...                   ...                    ...
# 3897 2033-07-24          64.1                  62.0                   49.8
# 3898 2033-07-25          62.8                  60.0                   48.1
# 3899 2033-07-26          60.6                  68.0                   48.9
# 3900 2033-07-27          61.7                  64.0                   47.4
# 3901 2033-07-28          60.5                  61.0                   45.3
#
#        Average barometer (in   Average windspeed (mph  \
# ...

# %%
pip install pandas-profiling
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
weather
# Out:
#            Date   Temperature   Average humidity (%   Average dewpoint (°F  \
# 0    2022-01-01          37.8                  35.0                   12.7
# 1    2022-01-02          43.2                  32.0                   14.7
# 2    2022-01-03          25.7                  60.0                   12.7
# 3    2022-01-04           9.3                  67.0                    0.1
# 4    2022-01-05          23.5                  30.0                   -5.3
# ...         ...           ...                   ...                    ...
# 3897 2033-07-24          64.1                  62.0                   49.8
# 3898 2033-07-25          62.8                  60.0                   48.1
# 3899 2033-07-26          60.6                  68.0                   48.9
# 3900 2033-07-27          61.7                  64.0                   47.4
# 3901 2033-07-28          60.5                  61.0                   45.3
#
#        Average barometer (in   Average windspeed (mph  \
# ...

# %%
weather.describe()
# Out:
#         Temperature   Average humidity (%   Average dewpoint (°F  \
# count   3901.000000           3901.000000            3901.000000
# mean      44.672417             48.881312              23.129813
# std       15.328397             17.439169              14.634936
# min      -12.100000              9.000000             -22.200000
# 25%       33.700000             36.000000              12.100000
# 50%       45.100000             47.000000              22.500000
# 75%       58.000000             61.000000              35.400000
# max       76.300000             94.000000              55.100000
#
#         Average barometer (in   Average windspeed (mph  \
# count             3901.000000              3901.000000
# mean                29.881441                 5.757421
# std                  0.250423                 4.021950
# min                 28.200000                 0.000000
# 25%                 29.700000                 2.700000
# ...

# %%
weather
# Out:
#            Date   Temperature   Average humidity (%   Average dewpoint (°F  \
# 0    2022-01-01          37.8                  35.0                   12.7
# 1    2022-01-02          43.2                  32.0                   14.7
# 2    2022-01-03          25.7                  60.0                   12.7
# 3    2022-01-04           9.3                  67.0                    0.1
# 4    2022-01-05          23.5                  30.0                   -5.3
# ...         ...           ...                   ...                    ...
# 3897 2033-07-24          64.1                  62.0                   49.8
# 3898 2033-07-25          62.8                  60.0                   48.1
# 3899 2033-07-26          60.6                  68.0                   48.9
# 3900 2033-07-27          61.7                  64.0                   47.4
# 3901 2033-07-28          60.5                  61.0                   45.3
#
#        Average barometer (in   Average windspeed (mph  \
# ...

# %%
weather.to_csv("weather_forecasting_stage.csv",encoding='utf-8')
